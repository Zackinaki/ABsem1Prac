# %% [markdown]
# ## Задание 1 . Выберите любой продукт.
# Например ваш продукт
#
# ozon.ru
#
# citilink.ru
#
# telegram
#
# Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить

# %% [markdown]
# ### 1.telegram
#
# Приложению телеграмм важно размещение рекламмы от рекламмодателей. Я выделил метрики, к-ые определяют популярность продукта. По этим причинам рекламмодатели и привлекает телеграмм
#
# - Кол-во пользователей в день
# - Кол-во актив польз-лей(клики) в день
# - Время проведенное на платформе мессенджера польз-лем
# - Ретеншн(повторное подключение) пол-ля через 1, 7 дней, месяц, год
# - Активность пол-ля в мессенжере(сообщения в день, кол-во активн диалогов)
# - Кол-во сообщений об ошибке в мессенджере(мобил, десктоп версии)
# - Конверсия в продление в подписку(сколько польз-лей перешло с бесплат подписки на платную)

# %% [markdown]
# ## Задание 2. Сформулируйте 5-10 гипотез для выбранного продукта.

# %% [markdown]
# Для привлечения нов польз-лей приложения телеграмм можно привлечь рекламму.
#
# Для активизации старых польз-лей и привлечения новых можно ввести в базу чатов государственные(разбивка на всю страну, так и местные)службы.
#
# Сделать интерфейс приложения более комфортным глазу пол-ля, что увеличит время проведенное на платформе мессенджера польз-лем.
#
# Способствовать постингу всех ведущих каналов на платформе. Это позволит повторно возвращаться за новой информацией пол-лей.
#
# Сделать интуитивным сортировку, ведение, постинг каналов на мессенджере, что увеличит активность пол-лей.
#
# Проводить регулярные выловы багов в приложении, что сократит соообщений об ошибках от пол-лей, что в свою очередь сократит негативный опыт использования приложения.
#
# Отключение рекламмы для платной подписки послужит для перехода с беслатной на платную подписку
